# %%
#1)Downloaded the Dataset:abalone.csv

# %%
#2)Loading the Dataset
import pandas as pd
df=pd.read_csv("/content/abalone.csv")
df.head(10)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
# 5   I   0.425     0.300   0.095        0.3515          0.1410          0.0775
# 6   F   0.530     0.415   0.150        0.7775          0.2370          0.1415
# 7   F   0.545     0.425   0.125        0.7680          0.2940          0.1495
# 8   M   0.475     0.370   0.125        0.5095          0.2165          0.1125
# 9   F   0.550     0.440   0.150        0.8945          0.3145          0.1510
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# ...

# %%
#3)Visualizations
#Univariate Analysis
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
import matplotlib.pyplot as plot
import seaborn as sns

# %%
sns.countplot(df.Sex)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df.Length)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.histplot(df.Rings)

# %%
#Bivariate Analysis
sns.boxplot(df.Diameter,df.Height)
plot.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plot.scatter(df.Length,df.Height)
plot.show()

# %%
#Multivariate Analysis
sns.pairplot(df,hue="Rings",height=4)
plot.show()

# %%
#4)Perform descriptive statistics on the dataset
import numpy as np
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.count()
# Out:
# Sex               4177
# Length            4177
# Diameter          4177
# Height            4177
# Whole weight      4177
# Shucked weight    4177
# Viscera weight    4177
# Shell weight      4177
# Rings             4177
# dtype: int64

# %%
numeric_data = df.select_dtypes(include=[np.number]) 
categorical_data = df.select_dtypes(exclude=[np.number]) 
print("Total numerical variables: ", numeric_data.shape[1]) 
print("Total categorical variables: ", categorical_data.shape[1])
# Out:
# Total numerical variables:  8
# Total categorical variables:  1

# %%
#5)Handle the Missing values
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
#No missing values

# %%
#6)Find the outliers and replace the outliers
sns.boxplot(df.Diameter)
plot.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Replacing Outliers
import sklearn
from sklearn.datasets import load_boston 
Q1 = np.percentile(df['Diameter'], 25, interpolation = 'midpoint') 
Q3 = np.percentile(df['Diameter'], 75, interpolation = 'midpoint') 
IQR = Q3 - Q1 
print("Old Shape: ", df.shape) 
upper = np.where(df['Diameter'] >= (Q3+1.5*IQR)) 
lower = np.where(df['Diameter'] <= (Q1-1.5*IQR)) 
df.drop(upper[0], inplace = True) 
df.drop(lower[0], inplace = True) 
print("New Shape: ", df.shape) 
sns.boxplot(x='Diameter', data=df)
# Out:
# Old Shape:  (4177, 9)
# New Shape:  (4118, 9)

# %%
#7)Check for Categorical columns and perform encoding
print("Total Categorical variables: ", categorical_data.shape[1]) 
Categorical_variables = list(categorical_data.columns)
Categorical_variables
# Out:
# Total Categorical variables:  1
# ['Sex']

# %%
df['Sex'].value_counts()
# Out:
# M    1519
# F    1307
# I    1292
# Name: Sex, dtype: int64

# %%
CleanSex={"Sex":{"M":0,"F":1,"I":2}}
df=df.replace(CleanSex)

# %%
df.head(5)
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    0   0.455     0.365   0.095        0.5140          0.2245
# 1    0   0.350     0.265   0.090        0.2255          0.0995
# 2    1   0.530     0.420   0.135        0.6770          0.2565
# 3    0   0.440     0.365   0.125        0.5160          0.2155
# 4    2   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %%
#8)Split the data into dependent and independent variables
X=df.iloc[:,:-1].values
print(X)
# Out:
# [[0.     0.455  0.365  ... 0.2245 0.101  0.15  ]
#  [0.     0.35   0.265  ... 0.0995 0.0485 0.07  ]
#  [1.     0.53   0.42   ... 0.2565 0.1415 0.21  ]
#  ...
#  [0.     0.6    0.475  ... 0.5255 0.2875 0.308 ]
#  [1.     0.625  0.485  ... 0.531  0.261  0.296 ]
#  [0.     0.71   0.555  ... 0.9455 0.3765 0.495 ]]

# %%
Y=df.iloc[:,-1].values
print(Y)
# Out:
# [15  7  9 ...  9 10 12]

# %%
#9)Scale the independent variables
from sklearn.preprocessing import StandardScaler
object= StandardScaler()
# standardization 
scale_iv= object.fit_transform(X) 
print(scale_iv)
# Out:
# [[-1.14618949 -0.65145568 -0.49886313 ... -0.63686012 -0.75723081
#   -0.67025836]
#  [-1.14618949 -1.5766139  -1.56253276 ... -1.2061493  -1.24159927
#   -1.25237493]
#  [ 0.06686842  0.00937162  0.08615517 ... -0.4911221  -0.38357514
#   -0.23367093]
#  ...
#  [-1.14618949  0.62614376  0.67117347 ...  0.73398821  0.96343047
#    0.47942187]
#  [ 0.06686842  0.84641953  0.77754044 ...  0.75903694  0.71893972
#    0.39210439]
#  [-1.14618949  1.59535713  1.52210918 ...  2.64679985  1.78455033
#    1.84011936]]

# %%
#10)Split the data into training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.05, random_state=1)

# %%
X_train
# Out:
# array([[0.    , 0.645 , 0.5   , ..., 0.741 , 0.3715, 0.3845],
#        [2.    , 0.515 , 0.4   , ..., 0.25  , 0.1245, 0.17  ],
#        [0.    , 0.555 , 0.435 , ..., 0.341 , 0.1645, 0.214 ],
#        ...,
#        [1.    , 0.445 , 0.335 , ..., 0.2025, 0.1095, 0.1195],
#        [0.    , 0.62  , 0.485 , ..., 0.4655, 0.2195, 0.28  ],
#        [2.    , 0.3   , 0.23  , ..., 0.0435, 0.0265, 0.04  ]])

# %%
Y_train
# Out:
# array([ 9,  9, 11, ...,  6, 11,  8])

# %%
X_test
# Out:
# array([[0.    , 0.685 , 0.55  , ..., 0.813 , 0.387 , 0.49  ],
#        [2.    , 0.385 , 0.29  , ..., 0.1   , 0.0505, 0.076 ],
#        [0.    , 0.54  , 0.405 , ..., 0.4815, 0.1915, 0.202 ],
#        ...,
#        [0.    , 0.57  , 0.45  , ..., 0.477 , 0.1605, 0.2515],
#        [1.    , 0.645 , 0.49  , ..., 0.4935, 0.3155, 0.299 ],
#        [0.    , 0.46  , 0.36  , ..., 0.2165, 0.1105, 0.19  ]])

# %%
Y_test
# Out:
# array([11,  8,  9, 11,  6, 13, 11,  8, 11,  6, 11, 17, 10, 10, 11,  9, 10,
#        11,  7, 10,  9,  8,  8, 10,  7,  9, 20, 13, 10,  6,  7, 12,  7,  6,
#         7,  6,  9, 18, 13,  9, 11, 10,  9,  8, 10, 11,  9,  8, 13,  6,  9,
#         7, 10,  7,  7,  6, 17,  9,  8,  5, 11, 14,  7, 11,  9, 15,  7,  5,
#         9, 10,  9, 11, 25, 10, 12,  9, 14,  9, 11, 16, 11, 12, 20, 11, 16,
#        10,  8, 11, 12, 13, 10, 10, 14, 10,  9, 12, 18, 11, 10, 11,  5,  6,
#        10,  8,  8,  8,  6,  9, 10, 11, 13,  7, 11, 10,  6,  8, 18,  7,  8,
#         9,  9, 19,  9, 12, 15, 13, 10,  9,  8, 12, 10,  9, 15,  9,  9,  8,
#         8,  9, 13, 10,  4,  7, 10, 10,  8,  6,  7, 14,  9, 15, 14,  6, 11,
#         9, 10, 12, 10,  9,  9,  7, 12,  8,  7,  9,  9,  7, 11, 13,  9, 10,
#         6, 10,  6, 13,  8, 12, 12,  9, 14, 11, 10,  7, 12,  9,  9, 15, 14,
#        18,  9, 10,  9,  6,  9, 10,  9,  8,  7,  8, 10, 12,  9,  8,  9,  8,
#         9,  8])

# %%
#12,13,14 Build and test the model

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
y=model.predict(X_test)

# %%
from sklearn.metrics import r2_score
print("R2 Score:")
r2_score(Y_test,y)
# Out:
# R2 Score:
# 0.11677314427066077

# %%
from sklearn.linear_model import LinearRegression
model1=LinearRegression()
model1.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y1=model1.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error
print("R2 Score:")
r2_score(Y_test,y1)
# Out:
# R2 Score:
# 0.5239334245879008

# %%
print("Mean Absolute Score:")
mean_absolute_error(Y_test,y1)
# Out:
# Mean Absolute Score:
# 1.5888842835216892
